# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os
from sklearn.model_selection import TimeSeriesSplit
from sklearn.preprocessing import MinMaxScaler
import math
from sklearn.metrics import mean_squared_error, mean_absolute_error

os.environ["KMP_DUPLICATE_LIB_OK"]="True"

# %%
def process_FAA_hourly_data(filename):
    path = os.getcwd()
    pathfile = os.path.join(path,"data",filename)
    df_temps = pd.read_csv(pathfile, skiprows=16)
    df_temps = df_temps.iloc[:,:-1]
    df_temps = df_temps.loc[df_temps[df_temps.columns[0]] != df_temps.columns[0]]
    df_temps[df_temps.columns[1]] = df_temps[df_temps.columns[1]].apply(pd.to_numeric, downcast = "integer")
    df_temps[df_temps.columns[2:]] = df_temps[df_temps.columns[2:]].apply(pd.to_numeric, downcast = "float")
    df_temps = df_temps.set_index(pd.DatetimeIndex(df_temps[df_temps.columns[0]]))
    df_temps = df_temps.drop([df_temps.columns[0]], axis=1)
    return df_temps

# %%
df_kphl = process_FAA_hourly_data("faa_hourly-KPHL_20120101-20190101.csv")

# %%
df_kphl_useful = df_kphl.iloc[:,[1,7,8,9]]
df_kphl_temp = df_kphl.iloc[:,1]

# %%
#df_kphl_useful contains four different variables
start = df_kphl_useful.index[0]
end = df_kphl_useful.index[-1]
idx = pd.date_range(start, end, freq='H')

df_kphl_useful = df_kphl_useful.reindex(idx, fill_value = np.nan)

# %%
#df_kphl_temp contains only temperature data
start = df_kphl_temp.index[0]
end = df_kphl_temp.index[-1]
idx = pd.date_range(start, end, freq='H')

df_kphl_temp = df_kphl_temp.reindex(idx, fill_value = np.nan)

# %%
print("Start day four variables is {}".format(df_kphl_useful.index[0]))
print("End day four variables is {}".format(df_kphl_useful.index[-1]))
print("\n\n")
print("Start day for temperature is {}".format(df_kphl_useful.index[0]))
print("End day for temperature is {}".format(df_kphl_useful.index[-1]))
# Out:
# Start day four variables is 2012-01-01 00:00:00
# End day four variables is 2019-01-01 23:00:00
#
#
#
# Start day for temperature is 2012-01-01 00:00:00
# End day for temperature is 2019-01-01 23:00:00

# %%
#Get all four variables
def create_dataset(dataset, look_back=24):
    dataX, dataY = [], []
    for i in range(len(dataset)-look_back-1):
        a = dataset[i:(i+look_back), :].flatten()
        dataX.append(a)
        dataY.append(dataset[i + look_back, 0])
    return np.array(dataX), np.array(dataY)

# %%
temp = np.array(df_kphl_temp)
temp = temp.reshape(-1,1)

# %%
#Stacked auto encoder
from keras.layers import *
from keras.models import Model, Sequential
from keras.layers import Input, LSTM, RepeatVector, Dense, TimeDistributed
# Out:
# Using TensorFlow backend.

# %%
# split into train and test sets (67% of them are for train data)
temp = np.array(df_kphl_temp)
temp = temp.reshape(-1,1)
temp = np.nan_to_num(temp)

useful = np.array(df_kphl_useful)
useful = np.nan_to_num(useful)

# %%
# split into train and test sets (67% of them are for train data)

#Normalize the data
scaler_temp = MinMaxScaler(feature_range=(0, 1))
temp = scaler_temp.fit_transform(temp)

#Normalize the temperature
scaler = MinMaxScaler(feature_range=(0, 1))
useful = scaler.fit_transform(useful)

# %%
number_of_splits = 5
splits = TimeSeriesSplit(n_splits = number_of_splits)

# %%
def buildLSTMmodel(trainX, trainY, testX, testY,status):
    #build a model
    model = Sequential()
    model.add(LSTM(96, input_shape=(trainX.shape[1], trainX.shape[2])))
    model.add(Dense(1))
    model.compile(loss='mae', optimizer='adam')
    model.fit(trainX, trainY, epochs=60, batch_size=72, validation_data=(testX, testY), verbose=2, shuffle=False)
    
    #make predict
    testPredict = model.predict(testX)
    testPredict = scaler_temp.inverse_transform(testPredict)
    if status == "Temp":
        testY = scaler_temp.inverse_transform(testY)
    else:
        testY = scaler_temp.inverse_transform([testY])
    #calculate root mean squared error
    
    if status == "Temp":
        testScore = mean_absolute_error(testY, testPredict)
    else:
        testScore = mean_absolute_error(testY[0], testPredict[:,0])
    return testScore

# %%
score = 0

for train_index, test_index in splits.split(useful):
    train = useful[train_index]
    test = useful[test_index]
    print('Observations: %d' % (len(train) + len(test)))
    print('Training Observations: %d' % (len(train)))
    print('Testing Observations: %d' % (len(test)))
    look_back = 24
    trainX, trainY = create_dataset(train,look_back)
    testX, testY = create_dataset(test, look_back)
    trainX = np.reshape(trainX, (trainX.shape[0], 1, trainX.shape[1]))
    testX = np.reshape(testX, (testX.shape[0], 1, testX.shape[1]))
    s = buildLSTMmodel(trainX,trainY,testX,testY)
    score += s

print('Test Score : %.2f MSE' % (score/number_of_splits))
# Out:
# Observations: 20464
# Training Observations: 10232
# Testing Observations: 10232
# Train on 10207 samples, validate on 10207 samples
# Epoch 1/60
#  - 6s - loss: 0.0634 - val_loss: 0.0887
# Epoch 2/60
#  - 2s - loss: 0.0473 - val_loss: 0.0749
# Epoch 3/60
#  - 2s - loss: 0.0439 - val_loss: 0.0682
# Epoch 4/60
#  - 2s - loss: 0.0419 - val_loss: 0.0640
# Epoch 5/60
#  - 2s - loss: 0.0404 - val_loss: 0.0620
# Epoch 6/60
#  - 2s - loss: 0.0388 - val_loss: 0.0574
# Epoch 7/60
#  - 2s - loss: 0.0365 - val_loss: 0.0461
# Epoch 8/60
#  - 2s - loss: 0.0364 - val_loss: 0.0437
# Epoch 9/60
#  - 2s - loss: 0.0358 - val_loss: 0.0398
# Epoch 10/60
#  - 2s - loss: 0.0348 - val_loss: 0.0366
# Epoch 11/60
#  - 2s - loss: 0.0348 - val_loss: 0.0394
# Epoch 12/60
#  - 2s - loss: 0.0339 - val_loss: 0.0335
# Epoch 13/60
#  - 2s - loss: 0.0338 - val_loss: 0.0365
# Epoch 14/60
#  - 2s - loss: 0.0329 - val_loss: 0.0355
# Epoch 15/60
#  - 2s - loss: 0.0325 - val_loss: 0.0304
# Epoch 16/60
#  - 2s - loss: 0.0314 - val_loss: 0.0275
# Epoch 17/60
#  - 2s - loss: 0.0312 - val_loss: 0.0269
# Epoch 18/60
#  - 2s - loss: 0.0310 - val_loss: 0.0259
# Epoch 19/60
#  - 2s - loss: 0.0305 - val_loss: 0.0254
# Epoch 20/60
#  - 2s - loss: 0.0302 - val_loss: 0.0259
# Epoch 21/60
#  - 2s - loss: 0.0301 - val_loss: 0.0248
# Epoch 22/60
#  - 2s - loss: 0.0295 - val_loss: 0.0249
# Epoch 23/60
#  - 2s - loss: 0.0303 - val_loss: 0.0239
# Epoch 24/60
#  - 2s - loss: 0.0290 - val_loss: 0.0252
# Epoch 25/60
#  - 2s - loss: 0.0289 - val_loss: 0.0240
# Epoch 26/60
#  - 2s - loss: 0.0285 - val_loss: 0.0243
# Epoch 27/60
#  - 2s - loss: 0.0289 - val_loss: 0.0232
# Epoch 28/60
#  - 2s - loss: 0.0277 - val_loss: 0.0235
# Epoch 29/60
#  - 2s - loss: 0.0280 - val_loss: 0.0248
# Epoch 30/60
#  - 2s - loss: 0.0276 - val_loss: 0.0239
# Epoch 31/60
#  - 2s - loss: 0.0272 - val_loss: 0.0246
# Epoch 32/60
#  - 2s - loss: 0.0266 - val_loss: 0.0219
# Epoch 33/60
#  - 2s - loss: 0.0269 - val_loss: 0.0264
# Epoch 34/60
#  - 2s - loss: 0.0267 - val_loss: 0.0220
# Epoch 35/60
#  - 2s - loss: 0.0262 - val_loss: 0.0212
# Epoch 36/60
#  - 2s - loss: 0.0259 - val_loss: 0.0219
# Epoch 37/60
#  - 2s - loss: 0.0260 - val_loss: 0.0245
# Epoch 38/60
#  - 2s - loss: 0.0262 - val_loss: 0.0220
# Epoch 39/60
#  - 2s - loss: 0.0255 - val_loss: 0.0211
# Epoch 40/60
#  - 2s - loss: 0.0257 - val_loss: 0.0220
# Epoch 41/60
#  - 2s - loss: 0.0257 - val_loss: 0.0208
# Epoch 42/60
#  - 2s - loss: 0.0254 - val_loss: 0.0226
# Epoch 43/60
#  - 2s - loss: 0.0256 - val_loss: 0.0226
# Epoch 44/60
#  - 2s - loss: 0.0250 - val_loss: 0.0207
# Epoch 45/60
#  - 2s - loss: 0.0246 - val_loss: 0.0207
# Epoch 46/60
#  - 2s - loss: 0.0247 - val_loss: 0.0209
# Epoch 47/60
#  - 2s - loss: 0.0260 - val_loss: 0.0365
# Epoch 48/60
#  - 2s - loss: 0.0254 - val_loss: 0.0229
# Epoch 49/60
#  - 2s - loss: 0.0243 - val_loss: 0.0198
# Epoch 50/60
#  - 2s - loss: 0.0242 - val_loss: 0.0202
# Epoch 51/60
#  - 2s - loss: 0.0242 - val_loss: 0.0198
# Epoch 52/60
#  - 2s - loss: 0.0238 - val_loss: 0.0198
# Epoch 53/60
#  - 2s - loss: 0.0237 - val_loss: 0.0196
# Epoch 54/60
#  - 2s - loss: 0.0245 - val_loss: 0.0224
# Epoch 55/60
#  - 2s - loss: 0.0243 - val_loss: 0.0192
# Epoch 56/60
#  - 2s - loss: 0.0237 - val_loss: 0.0199
# Epoch 57/60
#  - 2s - loss: 0.0243 - val_loss: 0.0205
# Epoch 58/60
#  - 2s - loss: 0.0238 - val_loss: 0.0188
# Epoch 59/60
#  - 2s - loss: 0.0233 - val_loss: 0.0192
# Epoch 60/60
#  - 2s - loss: 0.0234 - val_loss: 0.0192
# [30.89999843 29.99999906 29.99999906 29.99999906 30.89999843 32.
#  32.         33.09999856 35.0999995  35.99999887 35.99999887 38.99999878
#  38.20000201 37.90000022 37.00000085 37.00000085 35.99999887 35.0999995
#  35.0999995  35.0999995 ]
# [33.70465  31.546534 30.65893  30.546455 30.67341  31.668629 33.446278
#  33.70733  33.469177 34.545975 35.57206  35.969437 37.876667 38.40785
#  38.40117  37.598602 37.243366 36.258595 35.4752   34.62587 ]
# Observations: 30696
# Training Observations: 20464
# Testing Observations: 10232
# Train on 20439 samples, validate on 10207 samples
# Epoch 1/60
#  - 7s - loss: 0.0582 - val_loss: 0.0542
# Epoch 2/60
#  - 3s - loss: 0.0458 - val_loss: 0.0460
# Epoch 3/60
#  - 4s - loss: 0.0414 - val_loss: 0.0419
# Epoch 4/60
#  - 4s - loss: 0.0379 - val_loss: 0.0381
# Epoch 5/60
#  - 3s - loss: 0.0342 - val_loss: 0.0328
# Epoch 6/60
#  - 3s - loss: 0.0313 - val_loss: 0.0307
# Epoch 7/60
#  - 3s - loss: 0.0309 - val_loss: 0.0302
# Epoch 8/60
#  - 3s - loss: 0.0291 - val_loss: 0.0266
# Epoch 9/60
#  - 3s - loss: 0.0285 - val_loss: 0.0238
# Epoch 10/60
#  - 3s - loss: 0.0273 - val_loss: 0.0247
# Epoch 11/60
#  - 3s - loss: 0.0264 - val_loss: 0.0294
# Epoch 12/60
#  - 3s - loss: 0.0262 - val_loss: 0.0262
# Epoch 13/60
#  - 3s - loss: 0.0263 - val_loss: 0.0257
# Epoch 14/60
#  - 3s - loss: 0.0256 - val_loss: 0.0226
# Epoch 15/60
#  - 3s - loss: 0.0248 - val_loss: 0.0202
# Epoch 16/60
#  - 3s - loss: 0.0236 - val_loss: 0.0210
# Epoch 17/60
#  - 3s - loss: 0.0238 - val_loss: 0.0184
# Epoch 18/60
#  - 3s - loss: 0.0249 - val_loss: 0.0189
# Epoch 19/60
#  - 3s - loss: 0.0246 - val_loss: 0.0228
# Epoch 20/60
#  - 3s - loss: 0.0248 - val_loss: 0.0200
# Epoch 21/60
#  - 3s - loss: 0.0225 - val_loss: 0.0171
# Epoch 22/60
#  - 3s - loss: 0.0223 - val_loss: 0.0168
# Epoch 23/60
#  - 3s - loss: 0.0241 - val_loss: 0.0203
# Epoch 24/60
#  - 3s - loss: 0.0221 - val_loss: 0.0177
# Epoch 25/60
#  - 3s - loss: 0.0257 - val_loss: 0.0199
# Epoch 26/60
#  - 3s - loss: 0.0222 - val_loss: 0.0174
# Epoch 27/60
#  - 3s - loss: 0.0227 - val_loss: 0.0231
# Epoch 28/60
#  - 3s - loss: 0.0249 - val_loss: 0.0211
# Epoch 29/60
#  - 3s - loss: 0.0218 - val_loss: 0.0169
# Epoch 30/60
#  - 3s - loss: 0.0216 - val_loss: 0.0171
# Epoch 31/60
#  - 3s - loss: 0.0223 - val_loss: 0.0200
# Epoch 32/60
#  - 3s - loss: 0.0215 - val_loss: 0.0171
# Epoch 33/60
#  - 3s - loss: 0.0243 - val_loss: 0.0212
# Epoch 34/60
#  - 3s - loss: 0.0243 - val_loss: 0.0192
# Epoch 35/60
#  - 3s - loss: 0.0222 - val_loss: 0.0208
# Epoch 36/60
#  - 3s - loss: 0.0207 - val_loss: 0.0163
# Epoch 37/60
#  - 3s - loss: 0.0207 - val_loss: 0.0163
# Epoch 38/60
#  - 3s - loss: 0.0227 - val_loss: 0.0221
# Epoch 39/60
#  - 3s - loss: 0.0206 - val_loss: 0.0165
# Epoch 40/60
#  - 3s - loss: 0.0205 - val_loss: 0.0156
# Epoch 41/60
#  - 3s - loss: 0.0206 - val_loss: 0.0159
# Epoch 42/60
#  - 3s - loss: 0.0226 - val_loss: 0.0198
# Epoch 43/60
#  - 3s - loss: 0.0212 - val_loss: 0.0157
# Epoch 44/60
#  - 3s - loss: 0.0202 - val_loss: 0.0162
# Epoch 45/60
#  - 3s - loss: 0.0204 - val_loss: 0.0190
# Epoch 46/60
#  - 3s - loss: 0.0202 - val_loss: 0.0160
# Epoch 47/60
#  - 3s - loss: 0.0203 - val_loss: 0.0172
# Epoch 48/60
#  - 3s - loss: 0.0209 - val_loss: 0.0201
# Epoch 49/60
#  - 3s - loss: 0.0201 - val_loss: 0.0166
# Epoch 50/60
#  - 3s - loss: 0.0201 - val_loss: 0.0180
# Epoch 51/60
#  - 4s - loss: 0.0199 - val_loss: 0.0169
# Epoch 52/60
#  - 3s - loss: 0.0196 - val_loss: 0.0155
# Epoch 53/60
#  - 3s - loss: 0.0204 - val_loss: 0.0210
# Epoch 54/60
#  - 3s - loss: 0.0201 - val_loss: 0.0191
# Epoch 55/60
#  - 5s - loss: 0.0197 - val_loss: 0.0157
# Epoch 56/60
#  - 5s - loss: 0.0196 - val_loss: 0.0163
# Epoch 57/60
#  - 4s - loss: 0.0199 - val_loss: 0.0198
# Epoch 58/60
#  - 12s - loss: 0.0199 - val_loss: 0.0193
# Epoch 59/60
#  - 7s - loss: 0.0206 - val_loss: 0.0194
# Epoch 60/60
#  - 10s - loss: 0.0199 - val_loss: 0.0197
# [65.99999793 69.10000044 69.10000044 69.10000044 69.10000044 69.10000044
#  66.90000332 64.         62.09999866 59.38999908 57.10000082 56.99999821
#  55.89999965 55.89999965 53.09999894 53.09999894 52.00000038 52.00000038
#  52.00000038 55.00000028]
# [67.49002  68.254036 69.94556  69.82507  69.0714   68.26681  67.44101
#  65.731636 62.9571   60.96323  58.86833  57.16387  56.73342  56.383907
#  56.319412 54.546207 54.086254 53.421284 53.83897  54.863544]
# Observations: 40928
# Training Observations: 30696
# Testing Observations: 10232
# Train on 30671 samples, validate on 10207 samples
# Epoch 1/60
#  - 18s - loss: 0.0512 - val_loss: 0.0442
# Epoch 2/60
#  - 7s - loss: 0.0401 - val_loss: 0.0348
# Epoch 3/60
#  - 7s - loss: 0.0356 - val_loss: 0.0324
# Epoch 4/60
#  - 8s - loss: 0.0296 - val_loss: 0.0241
# Epoch 5/60
#  - 6s - loss: 0.0275 - val_loss: 0.0228
# Epoch 6/60
#  - 6s - loss: 0.0268 - val_loss: 0.0215
# Epoch 7/60
#  - 7s - loss: 0.0249 - val_loss: 0.0204
# Epoch 8/60
#  - 6s - loss: 0.0252 - val_loss: 0.0215
# Epoch 9/60
#  - 6s - loss: 0.0239 - val_loss: 0.0215
# Epoch 10/60
#  - 5s - loss: 0.0238 - val_loss: 0.0206
# Epoch 11/60
#  - 6s - loss: 0.0231 - val_loss: 0.0201
# Epoch 12/60
#  - 5s - loss: 0.0231 - val_loss: 0.0178
# Epoch 13/60
#  - 8s - loss: 0.0219 - val_loss: 0.0202
# Epoch 14/60
#  - 6s - loss: 0.0211 - val_loss: 0.0178
# Epoch 15/60
#  - 5s - loss: 0.0220 - val_loss: 0.0178
# Epoch 16/60
#  - 5s - loss: 0.0225 - val_loss: 0.0176
# Epoch 17/60
#  - 5s - loss: 0.0223 - val_loss: 0.0189
# Epoch 18/60
#  - 5s - loss: 0.0202 - val_loss: 0.0165
# Epoch 19/60
#  - 6s - loss: 0.0200 - val_loss: 0.0183
# Epoch 20/60
#  - 6s - loss: 0.0204 - val_loss: 0.0166
# Epoch 21/60
#  - 5s - loss: 0.0198 - val_loss: 0.0175
# Epoch 22/60
#  - 5s - loss: 0.0214 - val_loss: 0.0160
# Epoch 23/60
#  - 5s - loss: 0.0201 - val_loss: 0.0158
# Epoch 24/60
#  - 6s - loss: 0.0214 - val_loss: 0.0156
# Epoch 25/60
#  - 6s - loss: 0.0194 - val_loss: 0.0169
# Epoch 26/60
#  - 6s - loss: 0.0194 - val_loss: 0.0156
# Epoch 27/60
#  - 6s - loss: 0.0192 - val_loss: 0.0156
# Epoch 28/60
#  - 6s - loss: 0.0187 - val_loss: 0.0183
# Epoch 29/60
#  - 6s - loss: 0.0201 - val_loss: 0.0144
# Epoch 30/60
#  - 5s - loss: 0.0187 - val_loss: 0.0161
# Epoch 31/60
#  - 6s - loss: 0.0185 - val_loss: 0.0173
# Epoch 32/60
#  - 6s - loss: 0.0201 - val_loss: 0.0158
# Epoch 33/60
#  - 5s - loss: 0.0181 - val_loss: 0.0160
# Epoch 34/60
#  - 5s - loss: 0.0189 - val_loss: 0.0148
# Epoch 35/60
#  - 5s - loss: 0.0183 - val_loss: 0.0173
# Epoch 36/60
#  - 5s - loss: 0.0203 - val_loss: 0.0148
# Epoch 37/60
#  - 5s - loss: 0.0202 - val_loss: 0.0146
# Epoch 38/60
#  - 5s - loss: 0.0182 - val_loss: 0.0141
# Epoch 39/60
#  - 5s - loss: 0.0174 - val_loss: 0.0170
# Epoch 40/60
#  - 5s - loss: 0.0177 - val_loss: 0.0148
# Epoch 41/60
#  - 5s - loss: 0.0182 - val_loss: 0.0151
# Epoch 42/60
#  - 5s - loss: 0.0178 - val_loss: 0.0148
# Epoch 43/60
#  - 5s - loss: 0.0192 - val_loss: 0.0139
# Epoch 44/60
#  - 7s - loss: 0.0174 - val_loss: 0.0149
# Epoch 45/60
#  - 7s - loss: 0.0172 - val_loss: 0.0143
# Epoch 46/60
#  - 5s - loss: 0.0175 - val_loss: 0.0162
# Epoch 47/60
#  - 6s - loss: 0.0175 - val_loss: 0.0154
# Epoch 48/60
#  - 6s - loss: 0.0170 - val_loss: 0.0140
# Epoch 49/60
#  - 6s - loss: 0.0171 - val_loss: 0.0161
# Epoch 50/60
#  - 8s - loss: 0.0170 - val_loss: 0.0157
# Epoch 51/60
#  - 12s - loss: 0.0169 - val_loss: 0.0169
# Epoch 52/60
#  - 6s - loss: 0.0183 - val_loss: 0.0163
# Epoch 53/60
#  - 6s - loss: 0.0174 - val_loss: 0.0159
# Epoch 54/60
#  - 6s - loss: 0.0177 - val_loss: 0.0143
# Epoch 55/60
#  - 6s - loss: 0.0162 - val_loss: 0.0138
# Epoch 56/60
#  - 7s - loss: 0.0169 - val_loss: 0.0145
# Epoch 57/60
#  - 7s - loss: 0.0158 - val_loss: 0.0142
# Epoch 58/60
#  - 5s - loss: 0.0164 - val_loss: 0.0133
# Epoch 59/60
#  - 5s - loss: 0.0158 - val_loss: 0.0143
# Epoch 60/60
#  - 5s - loss: 0.0169 - val_loss: 0.0141
# [75.90000304 73.89999909 72.99999972 71.99999774 71.99999774 69.99999981
#  71.09999837 69.99999981 69.99999981 69.99999981 69.99999981 71.55000407
#  73.89999909 74.99999765 77.0000016  75.90000304 72.99999972 73.30000151
#  74.99999765 74.99999765]
# [76.55602  74.359795 72.537476 71.79993  71.178925 71.11479  69.704094
#  70.42753  70.29964  70.42534  71.02098  71.21219  72.76006  75.36751
#  77.30496  78.93258  78.127235 74.18733  73.33676  74.58184 ]
# Observations: 51160
# Training Observations: 40928
# Testing Observations: 10232
# Train on 40903 samples, validate on 10207 samples
# Epoch 1/60
#  - 13s - loss: 0.0464 - val_loss: 0.0530
# Epoch 2/60
#  - 7s - loss: 0.0334 - val_loss: 0.0594
# Epoch 3/60
#  - 8s - loss: 0.0293 - val_loss: 0.0578
# Epoch 4/60
#  - 10s - loss: 0.0268 - val_loss: 0.0484
# Epoch 5/60
#  - 6s - loss: 0.0258 - val_loss: 0.0498
# Epoch 6/60
#  - 7s - loss: 0.0242 - val_loss: 0.0301
# Epoch 7/60
#  - 6s - loss: 0.0233 - val_loss: 0.0376
# Epoch 8/60
#  - 8s - loss: 0.0237 - val_loss: 0.0339
# Epoch 9/60
#  - 9s - loss: 0.0222 - val_loss: 0.0321
# Epoch 10/60
#  - 7s - loss: 0.0224 - val_loss: 0.0280
# Epoch 11/60
#  - 9s - loss: 0.0212 - val_loss: 0.0375
# Epoch 12/60
#  - 12s - loss: 0.0210 - val_loss: 0.0404
# Epoch 13/60
#  - 7s - loss: 0.0200 - val_loss: 0.0350
# Epoch 14/60
#  - 7s - loss: 0.0207 - val_loss: 0.0257
# Epoch 15/60
#  - 8s - loss: 0.0200 - val_loss: 0.0388
# Epoch 16/60
#  - 8s - loss: 0.0204 - val_loss: 0.0298
# Epoch 17/60
#  - 9s - loss: 0.0194 - val_loss: 0.0300
# Epoch 18/60
#  - 7s - loss: 0.0200 - val_loss: 0.0196
# Epoch 19/60
#  - 6s - loss: 0.0190 - val_loss: 0.0167
# Epoch 20/60
#  - 7s - loss: 0.0190 - val_loss: 0.0177
# Epoch 21/60
#  - 8s - loss: 0.0193 - val_loss: 0.0242
# Epoch 22/60
#  - 9s - loss: 0.0184 - val_loss: 0.0239
# Epoch 23/60
#  - 7s - loss: 0.0181 - val_loss: 0.0265
# Epoch 24/60
#  - 8s - loss: 0.0189 - val_loss: 0.0225
# Epoch 25/60
#  - 7s - loss: 0.0185 - val_loss: 0.0170
# Epoch 26/60
#  - 7s - loss: 0.0183 - val_loss: 0.0223
# Epoch 27/60
#  - 7s - loss: 0.0190 - val_loss: 0.0266
# Epoch 28/60
#  - 7s - loss: 0.0179 - val_loss: 0.0310
# Epoch 29/60
#  - 8s - loss: 0.0184 - val_loss: 0.0157
# Epoch 30/60
#  - 6s - loss: 0.0184 - val_loss: 0.0253
# Epoch 31/60
#  - 7s - loss: 0.0173 - val_loss: 0.0197
# Epoch 32/60
#  - 7s - loss: 0.0174 - val_loss: 0.0253
# Epoch 33/60
#  - 7s - loss: 0.0186 - val_loss: 0.0199
# Epoch 34/60
#  - 7s - loss: 0.0180 - val_loss: 0.0218
# Epoch 35/60
#  - 7s - loss: 0.0170 - val_loss: 0.0315
# Epoch 36/60
#  - 8s - loss: 0.0172 - val_loss: 0.0263
# Epoch 37/60
#  - 11s - loss: 0.0175 - val_loss: 0.0342
# Epoch 38/60
#  - 8s - loss: 0.0175 - val_loss: 0.0272
# Epoch 39/60
#  - 7s - loss: 0.0170 - val_loss: 0.0179
# Epoch 40/60
#  - 10s - loss: 0.0173 - val_loss: 0.0268
# Epoch 41/60
#  - 8s - loss: 0.0170 - val_loss: 0.0244
# Epoch 42/60
#  - 10s - loss: 0.0171 - val_loss: 0.0205
# Epoch 43/60
#  - 8s - loss: 0.0168 - val_loss: 0.0152
# Epoch 44/60
#  - 7s - loss: 0.0166 - val_loss: 0.0251
# Epoch 45/60
#  - 8s - loss: 0.0169 - val_loss: 0.0178
# Epoch 46/60
#  - 8s - loss: 0.0170 - val_loss: 0.0274
# Epoch 47/60
#  - 8s - loss: 0.0171 - val_loss: 0.0273
# Epoch 48/60
#  - 9s - loss: 0.0168 - val_loss: 0.0264
# Epoch 49/60
#  - 8s - loss: 0.0167 - val_loss: 0.0253
# Epoch 50/60
#  - 7s - loss: 0.0159 - val_loss: 0.0194
# Epoch 51/60
#  - 7s - loss: 0.0160 - val_loss: 0.0247
# Epoch 52/60
#  - 8s - loss: 0.0169 - val_loss: 0.0277
# Epoch 53/60
#  - 8s - loss: 0.0166 - val_loss: 0.0150
# Epoch 54/60
#  - 7s - loss: 0.0160 - val_loss: 0.0252
# Epoch 55/60
#  - 7s - loss: 0.0169 - val_loss: 0.0392
# Epoch 56/60
#  - 7s - loss: 0.0160 - val_loss: 0.0236
# Epoch 57/60
#  - 7s - loss: 0.0160 - val_loss: 0.0271
# Epoch 58/60
#  - 7s - loss: 0.0164 - val_loss: 0.0365
# Epoch 59/60
#  - 7s - loss: 0.0164 - val_loss: 0.0246
# Epoch 60/60
#  - 9s - loss: 0.0164 - val_loss: 0.0259
# [64.89999937 64.         64.         65.99999793 69.10000044 72.99999972
#  74.99999765 77.0000016  78.10000016 81.99999944 80.99999746 81.99999944
#  80.99999746 78.99999953 77.0000016  75.90000304 73.89999909 71.99999774
#  71.99999774 71.09999837]
# [65.92095  65.26221  64.65765  64.95643  66.82262  70.2796   74.442245
#  77.121826 79.411545 80.93912  83.71881  83.142136 83.26433  81.87388
#  79.52818  76.975746 75.34929  73.60736  71.50741  71.315384]
# Observations: 61392
# Training Observations: 51160
# Testing Observations: 10232
# Train on 51135 samples, validate on 10207 samples
# Epoch 1/60
#  - 17s - loss: 0.0456 - val_loss: 0.0515
# Epoch 2/60
#  - 9s - loss: 0.0311 - val_loss: 0.0252
# Epoch 3/60
#  - 11s - loss: 0.0282 - val_loss: 0.0220
# Epoch 4/60
#  - 13s - loss: 0.0254 - val_loss: 0.0213
# Epoch 5/60
#  - 15s - loss: 0.0239 - val_loss: 0.0219
# Epoch 6/60
#  - 10s - loss: 0.0229 - val_loss: 0.0194
# Epoch 7/60
#  - 10s - loss: 0.0218 - val_loss: 0.0226
# Epoch 8/60
#  - 9s - loss: 0.0216 - val_loss: 0.0193
# Epoch 9/60
#  - 13s - loss: 0.0220 - val_loss: 0.0233
# Epoch 10/60
#  - 9s - loss: 0.0208 - val_loss: 0.0212
# Epoch 11/60
#  - 9s - loss: 0.0200 - val_loss: 0.0195
# Epoch 12/60
#  - 9s - loss: 0.0201 - val_loss: 0.0239
# Epoch 13/60
#  - 9s - loss: 0.0195 - val_loss: 0.0225
# Epoch 14/60
#  - 9s - loss: 0.0192 - val_loss: 0.0179
# Epoch 15/60
#  - 9s - loss: 0.0191 - val_loss: 0.0221
# Epoch 16/60
#  - 9s - loss: 0.0196 - val_loss: 0.0224
# Epoch 17/60
#  - 9s - loss: 0.0192 - val_loss: 0.0194
# Epoch 18/60
#  - 8s - loss: 0.0190 - val_loss: 0.0206
# Epoch 19/60
#  - 9s - loss: 0.0184 - val_loss: 0.0212
# Epoch 20/60
#  - 9s - loss: 0.0182 - val_loss: 0.0250
# Epoch 21/60
#  - 9s - loss: 0.0187 - val_loss: 0.0192
# Epoch 22/60
#  - 9s - loss: 0.0178 - val_loss: 0.0245
# Epoch 23/60
#  - 9s - loss: 0.0178 - val_loss: 0.0199
# Epoch 24/60
#  - 9s - loss: 0.0181 - val_loss: 0.0228
# Epoch 25/60
#  - 10s - loss: 0.0174 - val_loss: 0.0151
# Epoch 26/60
#  - 10s - loss: 0.0176 - val_loss: 0.0188
# Epoch 27/60
#  - 11s - loss: 0.0176 - val_loss: 0.0225
# Epoch 28/60
#  - 13s - loss: 0.0176 - val_loss: 0.0164
# Epoch 29/60
#  - 10s - loss: 0.0172 - val_loss: 0.0208
# Epoch 30/60
#  - 10s - loss: 0.0167 - val_loss: 0.0220
# Epoch 31/60
#  - 10s - loss: 0.0169 - val_loss: 0.0247
# Epoch 32/60
#  - 10s - loss: 0.0168 - val_loss: 0.0257
# Epoch 33/60
#  - 10s - loss: 0.0164 - val_loss: 0.0198
# Epoch 34/60
#  - 10s - loss: 0.0169 - val_loss: 0.0218
# Epoch 35/60
#  - 11s - loss: 0.0163 - val_loss: 0.0201
# Epoch 36/60
#  - 10s - loss: 0.0165 - val_loss: 0.0175
# Epoch 37/60
#  - 11s - loss: 0.0161 - val_loss: 0.0234
# Epoch 38/60
#  - 10s - loss: 0.0162 - val_loss: 0.0218
# Epoch 39/60
#  - 9s - loss: 0.0162 - val_loss: 0.0203
# Epoch 40/60
#  - 10s - loss: 0.0162 - val_loss: 0.0176
# Epoch 41/60
#  - 11s - loss: 0.0158 - val_loss: 0.0180
# Epoch 42/60
#  - 10s - loss: 0.0160 - val_loss: 0.0199
# Epoch 43/60
#  - 9s - loss: 0.0160 - val_loss: 0.0184
# Epoch 44/60
#  - 9s - loss: 0.0158 - val_loss: 0.0164
# Epoch 45/60
#  - 9s - loss: 0.0157 - val_loss: 0.0186
# Epoch 46/60
#  - 9s - loss: 0.0153 - val_loss: 0.0182
# Epoch 47/60
#  - 10s - loss: 0.0156 - val_loss: 0.0195
# Epoch 48/60
#  - 9s - loss: 0.0154 - val_loss: 0.0185
# Epoch 49/60
#  - 9s - loss: 0.0150 - val_loss: 0.0181
# Epoch 50/60
#  - 9s - loss: 0.0155 - val_loss: 0.0196
# Epoch 51/60
#  - 9s - loss: 0.0155 - val_loss: 0.0219
# Epoch 52/60
#  - 10s - loss: 0.0154 - val_loss: 0.0162
# Epoch 53/60
#  - 11s - loss: 0.0152 - val_loss: 0.0152
# Epoch 54/60
#  - 10s - loss: 0.0154 - val_loss: 0.0166
# Epoch 55/60
#  - 11s - loss: 0.0147 - val_loss: 0.0172
# Epoch 56/60
#  - 10s - loss: 0.0149 - val_loss: 0.0138
# Epoch 57/60
#  - 10s - loss: 0.0154 - val_loss: 0.0160
# Epoch 58/60
#  - 11s - loss: 0.0147 - val_loss: 0.0231
# Epoch 59/60
#  - 8s - loss: 0.0149 - val_loss: 0.0206
# Epoch 60/60
#  - 8s - loss: 0.0151 - val_loss: 0.0223
# [72.99999972 74.99999765 74.99999765 73.89999909 72.99999972 71.09999837
#  69.10000044 66.90000332 64.89999937 64.         62.99999803 62.09999866
#  61.00000009 59.00000216 57.9000036  56.99999821 57.9000036  57.9000036
#  57.9000036  59.00000216]
# [74.81686  76.53096  78.10715  77.261444 75.40006  73.717445 71.4765
#  69.40447  67.41861  65.68629  64.880745 64.12261  63.501453 62.492622
#  60.86443  59.85257  58.75432  59.191383 59.808575 60.523365]
# Test Score : 2.04 MSE

# %%
def create_datasettemp(dataset, look_back=24):
    dataX, dataY = [], []
    for i in range(len(dataset)-look_back-1):
        a = dataset[i:(i+look_back)].flatten()
        dataX.append(a)
        dataY.append(dataset[i + look_back])
    return np.array(dataX), np.array(dataY)

# %%
score = 0

for train_index, test_index in splits.split(useful):
    train = temp[train_index]
    test = temp[test_index]
    print('Observations: %d' % (len(train) + len(test)))
    print('Training Observations: %d' % (len(train)))
    print('Testing Observations: %d' % (len(test)))
    
    trainX, trainY = create_datasettemp(train)
    testX, testY = create_datasettemp(test)
    trainX = np.reshape(trainX, (trainX.shape[0], 1, trainX.shape[1]))
    testX = np.reshape(testX, (testX.shape[0], 1, testX.shape[1]))
    s = buildLSTMmodel(trainX,trainY,testX,testY,"Temp")
    score += s

print('Test Score : %.2f MSE' % (score/number_of_splits))
# Out:
# Observations: 20464
# Training Observations: 10232
# Testing Observations: 10232
# Train on 10207 samples, validate on 10207 samples
# Epoch 1/60
#  - 7s - loss: 0.0658 - val_loss: 0.0470
# Epoch 2/60
#  - 2s - loss: 0.0407 - val_loss: 0.0466
# Epoch 3/60
#  - 2s - loss: 0.0361 - val_loss: 0.0377
# Epoch 4/60
#  - 2s - loss: 0.0344 - val_loss: 0.0339
# Epoch 5/60
#  - 2s - loss: 0.0329 - val_loss: 0.0288
# Epoch 6/60
#  - 2s - loss: 0.0314 - val_loss: 0.0283
# Epoch 7/60
#  - 2s - loss: 0.0306 - val_loss: 0.0276
# Epoch 8/60
#  - 2s - loss: 0.0300 - val_loss: 0.0273
# Epoch 9/60
#  - 2s - loss: 0.0288 - val_loss: 0.0293
# Epoch 10/60
#  - 2s - loss: 0.0299 - val_loss: 0.0291
# Epoch 11/60
#  - 2s - loss: 0.0282 - val_loss: 0.0279
# Epoch 12/60
#  - 2s - loss: 0.0286 - val_loss: 0.0281
# Epoch 13/60
#  - 2s - loss: 0.0276 - val_loss: 0.0265
# Epoch 14/60
#  - 2s - loss: 0.0276 - val_loss: 0.0283
# Epoch 15/60
#  - 2s - loss: 0.0267 - val_loss: 0.0292
# Epoch 16/60
#  - 2s - loss: 0.0271 - val_loss: 0.0276
# Epoch 17/60
#  - 2s - loss: 0.0263 - val_loss: 0.0294
# Epoch 18/60
#  - 2s - loss: 0.0264 - val_loss: 0.0296
# Epoch 19/60
#  - 2s - loss: 0.0268 - val_loss: 0.0273
# Epoch 20/60
#  - 2s - loss: 0.0260 - val_loss: 0.0268
# Epoch 21/60
#  - 2s - loss: 0.0259 - val_loss: 0.0276
# Epoch 22/60
#  - 2s - loss: 0.0257 - val_loss: 0.0271
# Epoch 23/60
#  - 2s - loss: 0.0255 - val_loss: 0.0282
# Epoch 24/60
#  - 2s - loss: 0.0253 - val_loss: 0.0272
# Epoch 25/60
#  - 2s - loss: 0.0258 - val_loss: 0.0272
# Epoch 26/60
#  - 2s - loss: 0.0252 - val_loss: 0.0285
# Epoch 27/60
#  - 2s - loss: 0.0255 - val_loss: 0.0262
# Epoch 28/60
#  - 3s - loss: 0.0249 - val_loss: 0.0276
# Epoch 29/60
#  - 2s - loss: 0.0257 - val_loss: 0.0245
# Epoch 30/60
#  - 2s - loss: 0.0250 - val_loss: 0.0273
# Epoch 31/60
#  - 2s - loss: 0.0252 - val_loss: 0.0278
# Epoch 32/60
#  - 3s - loss: 0.0251 - val_loss: 0.0290
# Epoch 33/60
#  - 2s - loss: 0.0245 - val_loss: 0.0285
# Epoch 34/60
#  - 2s - loss: 0.0245 - val_loss: 0.0307
# Epoch 35/60
#  - 3s - loss: 0.0246 - val_loss: 0.0287
# Epoch 36/60
#  - 2s - loss: 0.0250 - val_loss: 0.0283
# Epoch 37/60
#  - 2s - loss: 0.0246 - val_loss: 0.0298
# Epoch 38/60
#  - 2s - loss: 0.0248 - val_loss: 0.0266
# Epoch 39/60
#  - 2s - loss: 0.0247 - val_loss: 0.0275
# Epoch 40/60
#  - 2s - loss: 0.0244 - val_loss: 0.0270
# Epoch 41/60
#  - 2s - loss: 0.0244 - val_loss: 0.0267
# Epoch 42/60
#  - 2s - loss: 0.0245 - val_loss: 0.0293
# Epoch 43/60
#  - 2s - loss: 0.0243 - val_loss: 0.0263
# Epoch 44/60
#  - 2s - loss: 0.0243 - val_loss: 0.0298
# Epoch 45/60
#  - 2s - loss: 0.0241 - val_loss: 0.0274
# Epoch 46/60
#  - 2s - loss: 0.0241 - val_loss: 0.0309
# Epoch 47/60
#  - 2s - loss: 0.0241 - val_loss: 0.0267
# Epoch 48/60
#  - 2s - loss: 0.0239 - val_loss: 0.0285
# Epoch 49/60
#  - 2s - loss: 0.0240 - val_loss: 0.0288
# Epoch 50/60
#  - 2s - loss: 0.0238 - val_loss: 0.0290
# Epoch 51/60
#  - 2s - loss: 0.0239 - val_loss: 0.0289
# Epoch 52/60
#  - 2s - loss: 0.0237 - val_loss: 0.0274
# Epoch 53/60
#  - 2s - loss: 0.0236 - val_loss: 0.0276
# Epoch 54/60
#  - 2s - loss: 0.0237 - val_loss: 0.0277
# Epoch 55/60
#  - 2s - loss: 0.0237 - val_loss: 0.0288
# Epoch 56/60
#  - 2s - loss: 0.0236 - val_loss: 0.0285
# Epoch 57/60
#  - 2s - loss: 0.0237 - val_loss: 0.0249
# Epoch 58/60
#  - 2s - loss: 0.0236 - val_loss: 0.0252
# Epoch 59/60
#  - 2s - loss: 0.0234 - val_loss: 0.0277
# Epoch 60/60
#  - 2s - loss: 0.0235 - val_loss: 0.0254
# [30.899998]
# [31.316872 30.306217 29.520708 29.545721 29.657072 30.667736 31.886593
#  32.023373 33.073044 34.93975  35.768135 35.669384 38.503284 37.839783
#  37.356808 36.26283  36.117874 35.04834  34.09188  34.052654]
# Observations: 30696
# Training Observations: 20464
# Testing Observations: 10232
# Train on 20439 samples, validate on 10207 samples
# Epoch 1/60
#  - 9s - loss: 0.0472 - val_loss: 0.0328
# Epoch 2/60
#  - 4s - loss: 0.0310 - val_loss: 0.0242
# Epoch 3/60
#  - 3s - loss: 0.0270 - val_loss: 0.0229
# Epoch 4/60
#  - 3s - loss: 0.0251 - val_loss: 0.0205
# Epoch 5/60
#  - 3s - loss: 0.0243 - val_loss: 0.0184
# Epoch 6/60
#  - 4s - loss: 0.0233 - val_loss: 0.0177
# Epoch 7/60
#  - 4s - loss: 0.0233 - val_loss: 0.0165
# Epoch 8/60
#  - 4s - loss: 0.0226 - val_loss: 0.0165
# Epoch 9/60
#  - 4s - loss: 0.0225 - val_loss: 0.0173
# Epoch 10/60
#  - 4s - loss: 0.0218 - val_loss: 0.0156
# Epoch 11/60
#  - 4s - loss: 0.0218 - val_loss: 0.0183
# Epoch 12/60
#  - 3s - loss: 0.0216 - val_loss: 0.0165
# Epoch 13/60
#  - 4s - loss: 0.0212 - val_loss: 0.0162
# Epoch 14/60
#  - 3s - loss: 0.0221 - val_loss: 0.0154
# Epoch 15/60
#  - 3s - loss: 0.0216 - val_loss: 0.0158
# Epoch 16/60
#  - 4s - loss: 0.0214 - val_loss: 0.0154
# Epoch 17/60
#  - 4s - loss: 0.0213 - val_loss: 0.0157
# Epoch 18/60
#  - 4s - loss: 0.0212 - val_loss: 0.0153
# Epoch 19/60
#  - 4s - loss: 0.0209 - val_loss: 0.0152
# Epoch 20/60
#  - 4s - loss: 0.0206 - val_loss: 0.0161
# Epoch 21/60
#  - 4s - loss: 0.0205 - val_loss: 0.0166
# Epoch 22/60
#  - 3s - loss: 0.0210 - val_loss: 0.0155
# Epoch 23/60
#  - 3s - loss: 0.0205 - val_loss: 0.0156
# Epoch 24/60
#  - 3s - loss: 0.0202 - val_loss: 0.0162
# Epoch 25/60
#  - 3s - loss: 0.0205 - val_loss: 0.0154
# Epoch 26/60
#  - 3s - loss: 0.0202 - val_loss: 0.0167
# Epoch 27/60
#  - 3s - loss: 0.0203 - val_loss: 0.0151
# Epoch 28/60
#  - 3s - loss: 0.0202 - val_loss: 0.0160
# Epoch 29/60
#  - 3s - loss: 0.0198 - val_loss: 0.0168
# Epoch 30/60
#  - 3s - loss: 0.0201 - val_loss: 0.0159
# Epoch 31/60
#  - 3s - loss: 0.0196 - val_loss: 0.0155
# Epoch 32/60
#  - 3s - loss: 0.0200 - val_loss: 0.0168
# Epoch 33/60
#  - 3s - loss: 0.0197 - val_loss: 0.0165
# Epoch 34/60
#  - 3s - loss: 0.0197 - val_loss: 0.0163
# Epoch 35/60
#  - 3s - loss: 0.0196 - val_loss: 0.0164
# Epoch 36/60
#  - 3s - loss: 0.0191 - val_loss: 0.0159
# Epoch 37/60
#  - 3s - loss: 0.0198 - val_loss: 0.0165
# Epoch 38/60
#  - 3s - loss: 0.0194 - val_loss: 0.0162
# Epoch 39/60
#  - 3s - loss: 0.0194 - val_loss: 0.0160
# Epoch 40/60
#  - 3s - loss: 0.0192 - val_loss: 0.0160
# Epoch 41/60
#  - 3s - loss: 0.0194 - val_loss: 0.0159
# Epoch 42/60
#  - 3s - loss: 0.0190 - val_loss: 0.0157
# Epoch 43/60
#  - 3s - loss: 0.0195 - val_loss: 0.0157
# Epoch 44/60
#  - 3s - loss: 0.0191 - val_loss: 0.0156
# Epoch 45/60
#  - 3s - loss: 0.0189 - val_loss: 0.0161
# Epoch 46/60
#  - 3s - loss: 0.0190 - val_loss: 0.0156
# Epoch 47/60
#  - 3s - loss: 0.0192 - val_loss: 0.0154
# Epoch 48/60
#  - 3s - loss: 0.0191 - val_loss: 0.0154
# Epoch 49/60
#  - 3s - loss: 0.0192 - val_loss: 0.0154
# Epoch 50/60
#  - 316s - loss: 0.0188 - val_loss: 0.0151
# Epoch 51/60
#  - 10s - loss: 0.0189 - val_loss: 0.0156
# Epoch 52/60
#  - 6s - loss: 0.0190 - val_loss: 0.0153
# Epoch 53/60
#  - 4s - loss: 0.0190 - val_loss: 0.0146
# Epoch 54/60
#  - 4s - loss: 0.0189 - val_loss: 0.0152
# Epoch 55/60
#  - 4s - loss: 0.0189 - val_loss: 0.0151
# Epoch 56/60
#  - 3s - loss: 0.0188 - val_loss: 0.0151
# Epoch 57/60
#  - 3s - loss: 0.0189 - val_loss: 0.0144
# Epoch 58/60
#  - 3s - loss: 0.0187 - val_loss: 0.0149
# Epoch 59/60
#  - 3s - loss: 0.0188 - val_loss: 0.0151
# Epoch 60/60
#  - 3s - loss: 0.0188 - val_loss: 0.0151
# [66.]
# [67.23528  68.10936  70.97649  70.54519  70.0003   69.54441  69.2559
#  66.857086 63.79024  61.788673 59.17488  56.827717 56.74874  55.854057
#  56.09292  53.61023  53.925205 53.207104 53.579906 53.838406]
# Observations: 40928
# Training Observations: 30696
# Testing Observations: 10232
# Train on 30671 samples, validate on 10207 samples
# Epoch 1/60
#  - 9s - loss: 0.0409 - val_loss: 0.0277
# Epoch 2/60
#  - 5s - loss: 0.0259 - val_loss: 0.0247
# Epoch 3/60
#  - 5s - loss: 0.0228 - val_loss: 0.0188
# Epoch 4/60
#  - 5s - loss: 0.0215 - val_loss: 0.0174
# Epoch 5/60
#  - 5s - loss: 0.0212 - val_loss: 0.0175
# Epoch 6/60
#  - 5s - loss: 0.0202 - val_loss: 0.0175
# Epoch 7/60
#  - 4s - loss: 0.0201 - val_loss: 0.0174
# Epoch 8/60
#  - 4s - loss: 0.0206 - val_loss: 0.0177
# Epoch 9/60
#  - 4s - loss: 0.0189 - val_loss: 0.0193
# Epoch 10/60
#  - 4s - loss: 0.0189 - val_loss: 0.0156
# Epoch 11/60
#  - 4s - loss: 0.0198 - val_loss: 0.0157
# Epoch 12/60
#  - 4s - loss: 0.0184 - val_loss: 0.0158
# Epoch 13/60
#  - 4s - loss: 0.0195 - val_loss: 0.0176
# Epoch 14/60
#  - 4s - loss: 0.0182 - val_loss: 0.0140
# Epoch 15/60
#  - 4s - loss: 0.0193 - val_loss: 0.0168
# Epoch 16/60
#  - 4s - loss: 0.0189 - val_loss: 0.0163
# Epoch 17/60
#  - 4s - loss: 0.0189 - val_loss: 0.0176
# Epoch 18/60
#  - 4s - loss: 0.0176 - val_loss: 0.0140
# Epoch 19/60
#  - 4s - loss: 0.0189 - val_loss: 0.0159
# Epoch 20/60
#  - 4s - loss: 0.0183 - val_loss: 0.0151
# Epoch 21/60
#  - 4s - loss: 0.0183 - val_loss: 0.0156
# Epoch 22/60
#  - 4s - loss: 0.0175 - val_loss: 0.0139
# Epoch 23/60
#  - 4s - loss: 0.0185 - val_loss: 0.0157
# Epoch 24/60
#  - 4s - loss: 0.0176 - val_loss: 0.0154
# Epoch 25/60
#  - 5s - loss: 0.0182 - val_loss: 0.0153
# Epoch 26/60
#  - 5s - loss: 0.0182 - val_loss: 0.0162
# Epoch 27/60
#  - 4s - loss: 0.0178 - val_loss: 0.0163
# Epoch 28/60
#  - 5s - loss: 0.0178 - val_loss: 0.0147
# Epoch 29/60
#  - 5s - loss: 0.0176 - val_loss: 0.0156
# Epoch 30/60
#  - 5s - loss: 0.0174 - val_loss: 0.0155
# Epoch 31/60
#  - 4s - loss: 0.0168 - val_loss: 0.0143
# Epoch 32/60
#  - 4s - loss: 0.0178 - val_loss: 0.0155
# Epoch 33/60
#  - 4s - loss: 0.0168 - val_loss: 0.0144
# Epoch 34/60
#  - 4s - loss: 0.0180 - val_loss: 0.0152
# Epoch 35/60
#  - 4s - loss: 0.0175 - val_loss: 0.0144
# Epoch 36/60
#  - 5s - loss: 0.0172 - val_loss: 0.0137
# Epoch 37/60
#  - 5s - loss: 0.0175 - val_loss: 0.0172
# Epoch 38/60
#  - 5s - loss: 0.0172 - val_loss: 0.0142
# Epoch 39/60
#  - 5s - loss: 0.0173 - val_loss: 0.0138
# Epoch 40/60
#  - 4s - loss: 0.0172 - val_loss: 0.0141
# Epoch 41/60
#  - 5s - loss: 0.0171 - val_loss: 0.0149
# Epoch 42/60
#  - 5s - loss: 0.0171 - val_loss: 0.0140
# Epoch 43/60
#  - 4s - loss: 0.0172 - val_loss: 0.0147
# Epoch 44/60
#  - 5s - loss: 0.0172 - val_loss: 0.0160
# Epoch 45/60
#  - 4s - loss: 0.0169 - val_loss: 0.0158
# Epoch 46/60
#  - 4s - loss: 0.0170 - val_loss: 0.0145
# Epoch 47/60
#  - 5s - loss: 0.0170 - val_loss: 0.0136
# Epoch 48/60
#  - 5s - loss: 0.0170 - val_loss: 0.0166
# Epoch 49/60
#  - 4s - loss: 0.0169 - val_loss: 0.0149
# Epoch 50/60
#  - 4s - loss: 0.0169 - val_loss: 0.0165
# Epoch 51/60
#  - 4s - loss: 0.0168 - val_loss: 0.0151
# Epoch 52/60
#  - 5s - loss: 0.0168 - val_loss: 0.0150
# Epoch 53/60
#  - 5s - loss: 0.0168 - val_loss: 0.0149
# Epoch 54/60
#  - 5s - loss: 0.0168 - val_loss: 0.0143
# Epoch 55/60
#  - 5s - loss: 0.0167 - val_loss: 0.0157
# Epoch 56/60
#  - 5s - loss: 0.0168 - val_loss: 0.0162
# Epoch 57/60
#  - 6s - loss: 0.0166 - val_loss: 0.0145
# Epoch 58/60
#  - 5s - loss: 0.0167 - val_loss: 0.0150
# Epoch 59/60
#  - 4s - loss: 0.0166 - val_loss: 0.0148
# Epoch 60/60
#  - 5s - loss: 0.0166 - val_loss: 0.0142
# [75.9]
# [75.921234 73.70221  71.80052  71.03026  70.22314  70.40041  68.69446
#  69.94931  69.32526  69.61972  69.96448  70.13739  71.888824 74.30212
#  75.41993  77.24388  75.82118  72.620476 72.50985  74.10692 ]
# Observations: 51160
# Training Observations: 40928
# Testing Observations: 10232
# Train on 40903 samples, validate on 10207 samples
# Epoch 1/60
#  - 11s - loss: 0.0383 - val_loss: 0.0279
# Epoch 2/60
#  - 7s - loss: 0.0231 - val_loss: 0.0265
# Epoch 3/60
#  - 7s - loss: 0.0212 - val_loss: 0.0206
# Epoch 4/60
#  - 6s - loss: 0.0201 - val_loss: 0.0198
# Epoch 5/60
#  - 7s - loss: 0.0189 - val_loss: 0.0215
# Epoch 6/60
#  - 6s - loss: 0.0190 - val_loss: 0.0177
# Epoch 7/60
#  - 6s - loss: 0.0181 - val_loss: 0.0237
# Epoch 8/60
#  - 7s - loss: 0.0186 - val_loss: 0.0217
# Epoch 9/60
#  - 6s - loss: 0.0177 - val_loss: 0.0194
# Epoch 10/60
#  - 8s - loss: 0.0180 - val_loss: 0.0207
# Epoch 11/60
#  - 8s - loss: 0.0176 - val_loss: 0.0166
# Epoch 12/60
#  - 6s - loss: 0.0178 - val_loss: 0.0169
# Epoch 13/60
#  - 6s - loss: 0.0177 - val_loss: 0.0217
# Epoch 14/60
#  - 6s - loss: 0.0170 - val_loss: 0.0195
# Epoch 15/60
#  - 6s - loss: 0.0174 - val_loss: 0.0186
# Epoch 16/60
#  - 7s - loss: 0.0176 - val_loss: 0.0222
# Epoch 17/60
#  - 6s - loss: 0.0174 - val_loss: 0.0256
# Epoch 18/60
#  - 7s - loss: 0.0174 - val_loss: 0.0370
# Epoch 19/60
#  - 6s - loss: 0.0172 - val_loss: 0.0226
# Epoch 20/60
#  - 6s - loss: 0.0172 - val_loss: 0.0393
# Epoch 21/60
#  - 6s - loss: 0.0171 - val_loss: 0.0293
# Epoch 22/60
#  - 6s - loss: 0.0171 - val_loss: 0.0317
# Epoch 23/60
#  - 6s - loss: 0.0172 - val_loss: 0.0215
# Epoch 24/60
#  - 7s - loss: 0.0168 - val_loss: 0.0204
# Epoch 25/60
#  - 6s - loss: 0.0166 - val_loss: 0.0282
# Epoch 26/60
#  - 6s - loss: 0.0169 - val_loss: 0.0205
# Epoch 27/60
#  - 6s - loss: 0.0164 - val_loss: 0.0310
# Epoch 28/60
#  - 7s - loss: 0.0169 - val_loss: 0.0229
# Epoch 29/60
#  - 7s - loss: 0.0167 - val_loss: 0.0195
# Epoch 30/60
#  - 6s - loss: 0.0166 - val_loss: 0.0219
# Epoch 31/60
#  - 6s - loss: 0.0165 - val_loss: 0.0193
# Epoch 32/60
#  - 6s - loss: 0.0162 - val_loss: 0.0301
# Epoch 33/60
#  - 6s - loss: 0.0167 - val_loss: 0.0196
# Epoch 34/60
#  - 6s - loss: 0.0164 - val_loss: 0.0194
# Epoch 35/60
#  - 6s - loss: 0.0164 - val_loss: 0.0166
# Epoch 36/60
#  - 6s - loss: 0.0164 - val_loss: 0.0198
# Epoch 37/60
#  - 6s - loss: 0.0164 - val_loss: 0.0206
# Epoch 38/60
#  - 6s - loss: 0.0164 - val_loss: 0.0188
# Epoch 39/60
#  - 6s - loss: 0.0163 - val_loss: 0.0190
# Epoch 40/60
#  - 6s - loss: 0.0161 - val_loss: 0.0188
# Epoch 41/60
#  - 6s - loss: 0.0161 - val_loss: 0.0171
# Epoch 42/60
#  - 6s - loss: 0.0161 - val_loss: 0.0166
# Epoch 43/60
#  - 6s - loss: 0.0161 - val_loss: 0.0186
# Epoch 44/60
#  - 6s - loss: 0.0162 - val_loss: 0.0189
# Epoch 45/60
#  - 6s - loss: 0.0161 - val_loss: 0.0193
# Epoch 46/60
#  - 6s - loss: 0.0161 - val_loss: 0.0191
# Epoch 47/60
#  - 6s - loss: 0.0159 - val_loss: 0.0244
# Epoch 48/60
#  - 6s - loss: 0.0162 - val_loss: 0.0178
# Epoch 49/60
#  - 6s - loss: 0.0159 - val_loss: 0.0230
# Epoch 50/60
#  - 6s - loss: 0.0161 - val_loss: 0.0180
# Epoch 51/60
#  - 6s - loss: 0.0159 - val_loss: 0.0181
# Epoch 52/60
#  - 6s - loss: 0.0159 - val_loss: 0.0186
# Epoch 53/60
#  - 6s - loss: 0.0159 - val_loss: 0.0205
# Epoch 54/60
#  - 6s - loss: 0.0159 - val_loss: 0.0172
# Epoch 55/60
#  - 8s - loss: 0.0158 - val_loss: 0.0208
# Epoch 56/60
#  - 7s - loss: 0.0158 - val_loss: 0.0216
# Epoch 57/60
#  - 6s - loss: 0.0158 - val_loss: 0.0232
# Epoch 58/60
#  - 6s - loss: 0.0160 - val_loss: 0.0180
# Epoch 59/60
#  - 6s - loss: 0.0157 - val_loss: 0.0210
# Epoch 60/60
#  - 6s - loss: 0.0158 - val_loss: 0.0222
# [64.9]
# [67.42088  66.52294  65.87908  66.16412  68.48915  72.00685  76.437355
#  78.61458  80.590614 81.42125  85.13446  83.42429  83.75301  81.908455
#  79.403656 77.04823  75.8726   73.974464 72.09267  72.193405]
# Observations: 61392
# Training Observations: 51160
# Testing Observations: 10232
# Train on 51135 samples, validate on 10207 samples
# Epoch 1/60
#  - 12s - loss: 0.0371 - val_loss: 0.0235
# Epoch 2/60
#  - 7s - loss: 0.0221 - val_loss: 0.0189
# Epoch 3/60
#  - 7s - loss: 0.0200 - val_loss: 0.0192
# Epoch 4/60
#  - 8s - loss: 0.0190 - val_loss: 0.0202
# Epoch 5/60
#  - 7s - loss: 0.0183 - val_loss: 0.0207
# Epoch 6/60
#  - 8s - loss: 0.0179 - val_loss: 0.0201
# Epoch 7/60
#  - 7s - loss: 0.0176 - val_loss: 0.0156
# Epoch 8/60
#  - 7s - loss: 0.0181 - val_loss: 0.0211
# Epoch 9/60
#  - 8s - loss: 0.0172 - val_loss: 0.0198
# Epoch 10/60
#  - 8s - loss: 0.0177 - val_loss: 0.0182
# Epoch 11/60
#  - 8s - loss: 0.0178 - val_loss: 0.0165
# Epoch 12/60
#  - 8s - loss: 0.0172 - val_loss: 0.0154
# Epoch 13/60
#  - 9s - loss: 0.0171 - val_loss: 0.0156
# Epoch 14/60
#  - 8s - loss: 0.0164 - val_loss: 0.0198
# Epoch 15/60
#  - 8s - loss: 0.0171 - val_loss: 0.0154
# Epoch 16/60
#  - 10s - loss: 0.0172 - val_loss: 0.0147
# Epoch 17/60
#  - 8s - loss: 0.0169 - val_loss: 0.0146
# Epoch 18/60
#  - 7s - loss: 0.0166 - val_loss: 0.0148
# Epoch 19/60
#  - 7s - loss: 0.0168 - val_loss: 0.0146
# Epoch 20/60
#  - 8s - loss: 0.0166 - val_loss: 0.0145
# Epoch 21/60
#  - 9s - loss: 0.0166 - val_loss: 0.0146
# Epoch 22/60
#  - 8s - loss: 0.0165 - val_loss: 0.0145
# Epoch 23/60
#  - 9s - loss: 0.0164 - val_loss: 0.0147
# Epoch 24/60
#  - 9s - loss: 0.0165 - val_loss: 0.0146
# Epoch 25/60
#  - 8s - loss: 0.0163 - val_loss: 0.0144
# Epoch 26/60
#  - 8s - loss: 0.0164 - val_loss: 0.0143
# Epoch 27/60
#  - 8s - loss: 0.0162 - val_loss: 0.0142
# Epoch 28/60
#  - 8s - loss: 0.0162 - val_loss: 0.0143
# Epoch 29/60
#  - 9s - loss: 0.0163 - val_loss: 0.0143
# Epoch 30/60
#  - 9s - loss: 0.0161 - val_loss: 0.0143
# Epoch 31/60
#  - 8s - loss: 0.0161 - val_loss: 0.0142
# Epoch 32/60
#  - 8s - loss: 0.0160 - val_loss: 0.0143
# Epoch 33/60
#  - 10s - loss: 0.0160 - val_loss: 0.0146
# Epoch 34/60
#  - 12s - loss: 0.0160 - val_loss: 0.0147
# Epoch 35/60
#  - 10s - loss: 0.0160 - val_loss: 0.0143
# Epoch 36/60
#  - 10s - loss: 0.0159 - val_loss: 0.0141
# Epoch 37/60
#  - 10s - loss: 0.0159 - val_loss: 0.0147
# Epoch 38/60
#  - 9s - loss: 0.0157 - val_loss: 0.0142
# Epoch 39/60
#  - 10s - loss: 0.0158 - val_loss: 0.0144
# Epoch 40/60
#  - 13s - loss: 0.0158 - val_loss: 0.0143
# Epoch 41/60
#  - 12s - loss: 0.0157 - val_loss: 0.0143
# Epoch 42/60
#  - 10s - loss: 0.0157 - val_loss: 0.0143
# Epoch 43/60
#  - 8s - loss: 0.0157 - val_loss: 0.0156
# Epoch 44/60
#  - 8s - loss: 0.0156 - val_loss: 0.0150
# Epoch 45/60
#  - 8s - loss: 0.0155 - val_loss: 0.0141
# Epoch 46/60
#  - 9s - loss: 0.0155 - val_loss: 0.0145
# Epoch 47/60
#  - 9s - loss: 0.0156 - val_loss: 0.0146
# Epoch 48/60
#  - 9s - loss: 0.0154 - val_loss: 0.0150
# Epoch 49/60
#  - 10s - loss: 0.0155 - val_loss: 0.0147
# Epoch 50/60
#  - 10s - loss: 0.0155 - val_loss: 0.0151
# Epoch 51/60
#  - 9s - loss: 0.0154 - val_loss: 0.0149
# Epoch 52/60
#  - 10s - loss: 0.0153 - val_loss: 0.0143
# Epoch 53/60
#  - 11s - loss: 0.0154 - val_loss: 0.0143
# Epoch 54/60
#  - 11s - loss: 0.0153 - val_loss: 0.0143
# Epoch 55/60
#  - 8s - loss: 0.0153 - val_loss: 0.0145
# Epoch 56/60
#  - 9s - loss: 0.0153 - val_loss: 0.0141
# Epoch 57/60
#  - 8s - loss: 0.0153 - val_loss: 0.0148
# Epoch 58/60
#  - 8s - loss: 0.0153 - val_loss: 0.0149
# Epoch 59/60
#  - 9s - loss: 0.0152 - val_loss: 0.0148
# Epoch 60/60
#  - 9s - loss: 0.0152 - val_loss: 0.0144
# [73.]
# [73.595695 75.06     76.60495  75.70578  73.82044  72.43927  70.10324
#  68.012566 65.893394 64.07839  63.381977 62.610146 61.818604 60.70573
#  58.70461  57.783966 57.230778 58.629997 59.2184   59.774254]
# Test Score : 1.84 MSE
